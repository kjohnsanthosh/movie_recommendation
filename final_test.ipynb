# %%
import pandas as pd

# %%
df = pd.read_csv('final.csv')

# %%
df['Director_name'] = df['Director_name'] / 2325
df ['Actor_names'] = df['Actor_names'] / 2048
df['production'] = df['production'] / 1290
df['year'] = df['year'] / 2017
df['original_language'] = df['original_language'] / 33

# %%
[df['Director_name'].max(), df['Actor_names'].max()]
# Out:
# [1.0, 1.0]

# %%
# df['Director_name'] = df['Director_name'] * 50
# df ['Actor_names'] = df['Actor_names'] * 50

# %%
df.head()
# Out:
#    movie_id                                     title  Actor_names  \
# 0     19995                                    Avatar     0.837891
# 1       285  Pirates of the Caribbean: At World's End     0.472656
# 2    206647                                   Spectre     0.209961
# 3     49026                     The Dark Knight Rises     0.172852
# 4     49529                               John Carter     0.916504
#
#    Director_name  original_language  \
# 0       0.374194           0.181818
# 1       0.324301           0.181818
# 2       0.837849           0.181818
# 3       0.152688           0.181818
# 4       0.040430           0.181818
#
#                                             overview      year  production  \
# 0  In the 22nd century, a paraplegic Marine is di...  0.996034    0.462016
# 1  Captain Barbossa, long believed to be dead, ha...  0.995042    0.958140
# 2  A cryptic message from Bond’s past sends him o...  0.999008    0.198450
# ...

# %%
df.to_csv('final3.csv', index=False)

# %%
df[df['title'] == 'The Wolf of Wall Street']
# Out:
#      movie_id                    title  Actor_names  Director_name  \
# 298    106646  The Wolf of Wall Street      0.57373       0.610753
#
#      original_language                                           overview  \
# 298           0.181818  A New York stockbroker refuses to cooperate in...
#
#          year  production  ratings  Thriller  ...  Comedy  Drama  Crime  War  \
# 298  0.998017    0.679845      7.9         0  ...      18     19     20    0
#
#      Action  Music  Western  Family  Documentary  Fantasy
# 298       0      0        0       0            0        0
#
# [1 rows x 27 columns]

# %%
df.describe()
# Out:
#             movie_id  Actor_names  Director_name  original_language  \
# count    4730.000000  4730.000000    4730.000000        4730.000000
# mean    53734.456025     0.503899       0.515811           0.194285
# std     84097.947635     0.288498       0.291763           0.082528
# min         5.000000     0.000000       0.000000           0.000000
# 25%      8961.500000     0.253906       0.263333           0.181818
# 50%     14302.500000     0.492432       0.523226           0.181818
# 75%     54564.500000     0.756226       0.778387           0.181818
# max    426469.000000     1.000000       1.000000           1.000000
#
#               year   production      ratings     Thriller    Adventure  \
# count  4730.000000  4730.000000  4730.000000  4730.000000  4730.000000
# mean      0.992732     0.574733     6.175835     2.676533     1.839535
# std       0.006175     0.294304     0.964165     4.427826     4.105430
# ...
